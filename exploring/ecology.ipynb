# %% [markdown]
# ## Temperature

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import altair as alt
from matplotlib import pyplot as plt
import hvplot.pandas
import holoviews as hv
from rasterstats import zonal_stats, gen_zonal_stats
import rasterio as rio
from rasterio.mask import mask
from rasterio import crs
from rasterio.warp import calculate_default_transform, reproject, Resampling

# %%
final_crs = crs.CRS.from_epsg('6564')

# %%
in_path='E:/graduate/musa509/assignment/LC08_L2SP_014032_20210927_20211001_02_T1_ST_B10.TIF'
out_path='E:/graduate/musa509/assignment/reproject.tif'

# %%
def reproject_raster(in_path, out_path):

    """
    """
    # reproject raster to project crs
    with rio.open(in_path) as src:
        src_crs = src.crs
        transform, width, height = calculate_default_transform(src_crs, final_crs, src.width, src.height, *src.bounds)
        profile = src.meta.copy()

        profile.update({
            'crs': final_crs,
            'transform': transform,
            'width': width,
            'height': height})

        with rio.open(out_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                reproject(
                    source=rio.band(src, i),
                    destination=rio.band(dst, i),
                    src_transform=src.transform,
                    src_crs=src.crs,
                    dst_transform=transform,
                    dst_crs=final_crs,
                    resampling=Resampling.nearest)
    return(out_path)

# %%
reproject_raster(in_path, out_path)
# Out:
# 'E:/graduate/musa509/assignment/reproject2.tif'

# %%
f = rio.open(out_path)

# %%
url = "http://data.phl.opendata.arcgis.com/datasets/405ec3da942d4e20869d4e1449a2be48_0.geojson"
city_limits = gpd.read_file("./city_limits.geojson")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte

# %%
city_limits = city_limits.to_crs(f.crs.data['init'])

# %%
masked_city, mask_transform = mask(
    dataset=f,
    shapes=city_limits.geometry,
    crop=True, 
    all_touched=True,  
    filled=False,  
)

# %%
temperature=masked_city[0]
temperature
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=0,
#   dtype=uint16)

# %%
def calculate_temperature(data):
    """
    Calculate the Fahrenheit from temparature tiff
    """
    
    # Convert to floats
    data = data.astype(float)
    
    # Get valid entries
    check = data.mask == False
    
    # Where the check is True, return the NDVI, else return NaN
    temperature = np.where(check,  1.8 * ((data * 0.00341802 + 149.0) - 273) + 32, np.nan )
    return temperature

# %%
temperature = calculate_temperature(temperature)

# %%
temperature
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
city_limits.total_bounds[3]
# Out:
# 92947.53307818821

# %%
landsat_extent = [
    city_limits.total_bounds[0],
    city_limits.total_bounds[2],
    city_limits.total_bounds[1],
    city_limits.total_bounds[3],
]

# %%
fig, ax = plt.subplots(figsize=(10,10))

# Plot temperature
img = ax.imshow(temperature, extent=landsat_extent)

# Format and plot city limits
city_limits.plot(ax=ax, edgecolor='gray', facecolor='none', linewidth=4)
plt.colorbar(img)
ax.set_axis_off()
ax.set_title("temperature in Philadelphia", fontsize=18);

# %%
hot_spots = np.where(temperature > 95, temperature, np.nan)

# %%
hot_spots
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
fig, ax = plt.subplots(figsize=(10,10))

# Plot temperature
img = ax.imshow(hot_spots, extent=landsat_extent)

# Format and plot city limits
city_limits.plot(ax=ax, edgecolor='gray', facecolor='none', linewidth=4)
plt.colorbar(img)
ax.set_axis_off()
ax.set_title("temperature in Philadelphia", fontsize=18);

# %%
cold_spots = np.where(temperature < 75, temperature, np.nan)

# %%
cold_spots
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
fig, ax = plt.subplots(figsize=(10,10))

# Plot temperature
img = ax.imshow(cold_spots, extent=landsat_extent)

# Format and plot city limits
city_limits.plot(ax=ax, edgecolor='gray', facecolor='none', linewidth=4)
plt.colorbar(img)
ax.set_axis_off()
ax.set_title("temperature in Philadelphia", fontsize=18);

# %% [markdown]
# ## Flood

# %%
park = gpd.read_file('https://opendata.arcgis.com/datasets/d52445160ab14380a673e5849203eb64_0.geojson')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte

# %%
park = park.to_crs(final_crs)
parkUnion = gpd.GeoSeries(park.geometry.unary_union)
parkUnion.plot(fc="None", ec="red")
# Out:
# <AxesSubplot:>

# %%
park
# Out:
#      OBJECTID                                     PUBLIC_NAME  \
# 0           1  William H (Billy) Markward Memorial Playground
# 1           2                                Schuylkill Banks
# 2           3                           Schuylkill River Park
# 3           4                           Frankford Boat Launch
# 4           5                            Orthodox Street Park
# ..        ...                                             ...
# 518       519      Fox Chase - Lorimer Trail Greenway (Rhawn)
# 519       520                      Philadelphia Museum of Art
# 520       521                                      Boone Park
# 521       522                     Loretto and Gilham Triangle
# 522       523                                  Spring Gardens
#
#                                     PARENT_NAME NESTED  \
# 0                         Schuylkill River Park      Y
# 1                              Schuylkill Banks      N
# 2                         Schuylkill River Park      N
# 3                         Frankford Boat Launch      N
# 4                          Orthodox Street Park      N
# ..                                          ...    ...
# 518  Fox Chase - Lorimer Trail Greenway (Rhawn)      N
# 519                         East Fairmount Park      Y
# 520                                  Boone Park      N
# 521                 Loretto and Gilham Triangle      N
# 522                              Spring Gardens      N
#
#                                        OFFICIAL_NAME  \
# 0    William H. (Billy) Markward Memorial Playground
# 1                                               None
# 2                                               None
# 3                              Frankford Boat Launch
# 4                                               None
# ..                                               ...
# 518                                             None
# 519                   The Philadelphia Museum of Art
# 520                                             None
# 521                                             None
# 522                               The Spring Gardens
#
#                             LABEL  \
# 0                       Markward
# 1                Schuylkill Banks
# 2           Schuylkill River Park
# 3           Frankford Boat Launch
# 4                        Orthodox
# ..                            ...
# 518  Fox Chase - Lorimer Greenway
# 519                 Museum of Art
# 520                         Boone
# 521            Loretto and Gilham
# 522            The Spring Gardens
#
#                                                  ALIAS  DPP_ASSET_ID  \
# 0                                                 None          1903
# 1                                Schuylkill River Park          2794
# 2                                                 None          2992
# 3         PA Fish & Boat;Frankford Arsenal Boat Launch          3090
# 4    Orthodox Street Parcel; Bridesburg Riverfront ...          3091
# ..                                                 ...           ...
# 518                                               None         99999
# 519                                 Art Museum Complex          3463
# 520                                      Manayunk Park           602
# 521  Cranford Ave andd Magee Ave Traffic Island; No...           245
# 522                                               None          3800
#
#                     ADDRESS_911 ZIP_CODE  ... PPR_OPS_DISTRICT  \
# 0                400 S TANEY ST    19146  ...             5, 7
# 1                400 S TANEY ST    19103  ...             5, 7
# 2                400 S TANEY ST    19146  ...             5, 7
# 3                5625 TACONY ST    19137  ...                2
# 4              3101 ORTHODOX ST    19137  ...                2
# ..                          ...      ...  ...              ...
# 518                439 RHAWN ST    19111  ...                1
# 519  2600 BENJAMIN FRANKLIN PKY    19130  ...                5
# 520               4200 BOONE ST    19128  ...                4
# 521              1385 GILHAM ST    19111  ...                1
# 522               1828 NORTH ST    19130  ...                6
#
#     COUNCIL_DISTRICT  POLICE_DISTRICT CITY_SCALE_MAPS LOCAL_SCALE_MAPS  \
# 0                  2                9               Y                Y
# 1               2, 5            9, 17               Y                Y
# 2                  2                9               Y                Y
# 3                  6               15               Y                Y
# 4                  6               15               Y                N
# ..               ...              ...             ...              ...
# 518               10                7               Y                N
# 519                5                9               N                Y
# 520                4                5               Y                N
# 521                9                2               Y                Y
# 522                5                9               Y                Y
#
#     PROGRAM_SITES                                           COMMENTS  \
# 0               Y                                               None
# 1               N    Bill 160113 (4/14/16) -South of South St Bridge
# 2               N                                               None
# 3               N                                               None
# 4               N  Officially acquired from PAID in 10/2019. Doc ...
# ..            ...                                                ...
# 518             N  No Public Access. Undeveloped Land awaiting Fo...
# 519             N                                               None
# 520             N                                               None
# 521             N                                               None
# 522             N                              Lease from 2021-2036.
#
#        Shape__Area Shape__Length  \
# 0     23295.664062    892.868012
# 1    101477.179688   9300.670289
# 2     50512.582031   1259.304657
# 3     78515.335938   1585.376114
# 4     72926.187500   1304.901416
# ..             ...           ...
# 518   24840.667969   2152.448099
# 519  169316.648438   1983.048997
# 520   12455.519531    909.895816
# 521    1116.867188    144.694698
# 522   13540.667969    489.451075
#
#                                               geometry
# 0    POLYGON ((819269.714 71453.463, 819280.058 714...
# 1    POLYGON ((819458.823 73175.103, 819482.793 731...
# 2    POLYGON ((819485.190 71505.217, 819481.641 714...
# 3    POLYGON ((829991.387 78364.563, 829986.780 783...
# 4    POLYGON ((829101.688 76401.248, 829096.724 764...
# ..                                                 ...
# 518  POLYGON ((827466.623 86648.560, 827466.676 866...
# 519  POLYGON ((819298.871 73450.807, 819301.716 734...
# 520  MULTIPOLYGON (((816016.046 80016.842, 816053.9...
# 521  POLYGON ((828056.486 82202.784, 828092.237 822...
# 522  POLYGON ((820509.039 73551.994, 820509.991 735...
#
# [523 rows x 26 columns]

# %%
flood100 = gpd.read_file('	https://opendata.arcgis.com/datasets/1d6d353ab50b4884b586c05ee2a661db_0.geojson')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 71: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 76: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte
# Exception ignored in: 'fiona._env.log_error'
# Traceback (most recent call last):
#   File "D:\Conda\envs\musa-550-fall-2021\lib\site-packages\fiona\env.py", line 283, in defenv
#     local._env.start()
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 67: invalid continuation byte

# %%
flood100 = flood100.to_crs(final_crs)
flood100.plot()
# Out:
# <AxesSubplot:>

# %%
flood100
# Out:
#      OBJECTID FLD_AR_ID FLD_ZONE  FLOODWAY SFHA_TF  STATIC_BFE V_DATUM  DEPTH  \
# 0           1        81       AE  FLOODWAY       T       -9999          -9999
# 1           2        82       AE  FLOODWAY       T       -9999          -9999
# 2           3        83       AE  FLOODWAY       T       -9999          -9999
# 3           4        84       AE  FLOODWAY       T       -9999          -9999
# 4           5        85       AE  FLOODWAY       T       -9999          -9999
# ..        ...       ...      ...       ...     ...         ...     ...    ...
# 375       376      1071       AE                 T          11  NGVD29  -9999
# 376       377      1072       AE                 T          11  NGVD29  -9999
# 377       378      1076       AE                 T          11  NGVD29  -9999
# 378       379      1079       AE                 T       -9999          -9999
# 379       380      1080       AE                 T       -9999          -9999
#
#     LEN_UNIT  VELOCITY VEL_UNIT AR_REVERT  BFE_REVERT  DEP_REVERT SOURCE_CIT  \
# 0                -9999                          -9999       -9999       FIS1
# 1                -9999                          -9999       -9999       FIS1
# 2                -9999                          -9999       -9999       FIS1
# 3                -9999                          -9999       -9999       FIS1
# 4                -9999                          -9999       -9999       FIS1
# ..       ...       ...      ...       ...         ...         ...        ...
# 375     FEET     -9999                          -9999       -9999       FIS2
# 376     FEET     -9999                          -9999       -9999       FIS2
# 377     FEET     -9999                          -9999       -9999       FIS2
# 378              -9999                          -9999       -9999       FIS1
# 379              -9999                          -9999       -9999       FIS2
#
#       Shape__Area  Shape__Length  \
# 0    8.063346e+06  174045.110643
# 1    3.994758e+05   16190.894773
# 2    1.654504e+07  124312.624296
# 3    3.138754e+07  177894.448578
# 4    8.896386e+04    2922.791269
# ..            ...            ...
# 375  5.680942e+04    2572.683356
# 376  4.572595e+04    1347.146566
# 377  2.555568e+07   99296.501190
# 378  2.818366e+06   47413.292751
# 379  3.441513e+06   15353.430915
#
#                                               geometry
# 0    POLYGON ((834814.703 91751.337, 834815.089 917...
# 1    POLYGON ((833970.126 92256.290, 833970.089 922...
# 2    POLYGON ((828374.049 87728.313, 828377.012 877...
# 3    POLYGON ((815474.330 86912.018, 815469.532 869...
# 4    POLYGON ((836430.149 83541.505, 836454.782 835...
# ..                                                 ...
# 375  POLYGON ((817265.478 63319.121, 817261.033 633...
# 376  POLYGON ((816765.699 62940.410, 816764.610 628...
# 377  POLYGON ((829408.932 78312.123, 829408.349 783...
# 378  POLYGON ((817145.977 78397.838, 817117.449 784...
# 379  POLYGON ((813312.913 65920.204, 813297.442 658...
#
# [380 rows x 18 columns]

# %%
buffer = park.geometry.buffer(500)

# %%
bufferUnion = gpd.GeoSeries(buffer.geometry.unary_union)

# %%
bufferUnion.plot()
# Out:
# <AxesSubplot:>

# %%
fig,axis = plt.subplots(figsize=(15,15))
flood100.plot(ec="blue",ax=axis)

bufferUnion.plot(fc="None", ec="red",ax=axis)
city_limits.plot(ax=axis, edgecolor='gray', facecolor='none', linewidth=4)
# Out:
# <AxesSubplot:>
